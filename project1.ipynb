# %% [markdown]
# <a href="https://colab.research.google.com/github/majasellmer/sose22/blob/main/project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Thu Apr 21 10:07:01 2022

# %% [markdown]
# This is *italic*, **bold**

# %% [markdown]
# $\sqrt{4}+e^{2i\varphi}$

# %%
print("a")
# Out:
# a

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.random.randn(200)
x = [x for x in range(len(y))]
plt.plot(x,y,'-')
plt.title("First plot")
plt.show()
